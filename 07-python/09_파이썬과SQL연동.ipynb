# %% [markdown]
# ### 데이터베이스(스키마)와 테이블 만들기

# %%
import pymysql

conn = pymysql.connect(
    host='127.0.0.1',
    user='root',
    password='qwer1234'
)
cur = conn.cursor()
cur.execute("CREATE DATABASE IF NOT EXISTS testdb")
conn.close()

# %%
conn = pymysql.connect(
    host='127.0.0.1',
    user='root',
    password='qwer1234',
    database='testdb'
)
cur = conn.cursor()
cur.execute("""
CREATE TABLE members 
(id INT AUTO_INCREMENT PRIMARY KEY,
 name VARCHAR(255), 
 address VARCHAR(255),
 email VARCHAR(255),
 phone_number VARCHAR(255),
 job VARCHAR(255),
 company VARCHAR(255)
 )
 """)
conn.commit()
print("테이블이 생성되었습니다.")
conn.close()

# %%
from faker import Faker
fake = Faker('ko-KR')
print(fake.name())
print(fake.address())
print(fake.email())
print(fake.phone_number())
print(fake.job())
print(fake.company())
# Out:
# 최예지
# 인천광역시 노원구 압구정83로 108
# fi@example.org
# 017-468-5723
# 기타 섬유 및 가죽 관련 기능 종사원
# (유) 고구려랩스

# %% [markdown]
# ### CRUD - INSERT
# - 데이터 추가

# %%
cur.execute("""INSERT INTO members (name, address, email, phone_number, job, company)
 VALUES 
 (%s, %s, %s, %s, %s, %s)""",
 (fake.name(), fake.address(), 
 fake.email(), fake.phone_number(),
  fake.job(), fake.company())
  )
conn.commit()
print("데이터가 삽입되었습니다.")
# Out:
# 데이터가 삽입되었습니다.

# %%
for i in range(10):
    cur.execute("""INSERT INTO members (name, address, email, phone_number, job, company)
     VALUES
        (%s, %s, %s, %s, %s, %s)""",
        (fake.name(), fake.address(),
         fake.email(), fake.phone_number(),
         fake.job(), fake.company())
    )
conn.commit()

# %%
# executemany : INSERT문 하나에 데이터 목록을 통째로 넘기면, 반복문 없이 여러 행을 한 번에 저장 가능
members = [fake.name(), fake.address(), fake.email(), fake.phone_number(), fake.job(), fake.company()]
members

cur.execute("""
 INSERT INTO members (name, address, email, phone_number, job, company)
 VALUES (%s, %s, %s, %s, %s, %s)
 """,(fake.name(), fake.address(), fake.email(), fake.phone_number(), fake.job(), fake.company()))
conn.commit()

print("데이터가 삽입되었습니다.")
# Out:
# 데이터가 삽입되었습니다.

# %% [markdown]
# ### CRUD - SELECT
# - 데이터 조회

# %%
cur.execute("SELECT * FROM members")
rows = cur.fetchall() # 전체조회
for row in rows:
    print(row)
# Out:
# (1, '장혜진', '경상북도 양구군 언주076거리 998-53 (명자김읍)', 'myeongsugseo@example.com', '055-619-4628', '금속 / 재료공학 연구원 및 기술자', '주식회사 나루윈드시스템')
# (2, '이성민', '부산광역시 영등포구 개포로 63-77 (성수최배동)', 'jeongsig45@example.com', '02-0976-8006', '인사 및 교육/훈련 사무원', '(유) 우리코어출판')
# (3, '허지우', '울산광역시 용산구 양재천로 207', 'seojun10@example.net', '044-609-4290', '시멘트 및 광물제품 제조기 조작원', '주식회사 이노')
# (4, '김경숙', '전북특별자치도 천안시 동남구 도산대거리 445-19', 'miyeongbaeg@example.com', '053-875-1914', '모피 및 가죽의복 제조원', '(유) 첨단')
# (5, '손경희', '서울특별시 은평구 반포대0가 지하152 (정숙김읍)', 'jihyecoe@example.com', '044-049-1421', '세탁원 및 다림질원', '유한회사 아름')
# (6, '김준호', '인천광역시 관악구 선릉가 347', 'munsunog@example.com', '063-464-3686', '기타 금융 및 보험 관련 전문가', '유한회사 다올')
# (7, '이재호', '충청북도 제천시 잠실길 862-16', 'cunjabag@example.org', '070-2803-9440', '법률관련 사무원', '(주) 마루첨단보안')
# (8, '최은주', '부산광역시 동구 백제고분6길 707-54 (도현엄리)', 'jongsu58@example.net', '042-563-5605', '금속 / 재료공학 시험원', '(유) 나루에이아이')
# (9, '차현숙', '경상북도 성남시 분당구 언주길 185 (지현박이읍)', 'bagsugja@example.net', '070-7695-7368', '방문 판매원', '주식회사 윈드에너지')
# (10, '황혜진', '충청북도 남양주시 백제고분187로 670-58', 'tgang@example.com', '018-989-5299', '재단사', '유한회사 글로벌코스메틱')
# (11, '김지현', '서울특별시 구로구 강남대길 67-44 (지영손김동)', 'sanghono@example.org', '019-451-1845', '웹 개발자', '(유) 푸른신문')
# (12, '진정훈', '인천광역시 종로구 양재천146로 27', 'minjaebag@example.com', '061-335-7778', '양식원', '유한회사 백제마음유통')

# %%
cur.execute("SELECT * FROM members WHERE ID = 1")
cur.fetchone() # 결과 조건이 1개
# Out:
# (1,
#  '장혜진',
#  '경상북도 양구군 언주076거리 998-53 (명자김읍)',
#  'myeongsugseo@example.com',
#  '055-619-4628',
#  '금속 / 재료공학 연구원 및 기술자',
#  '주식회사 나루윈드시스템')
